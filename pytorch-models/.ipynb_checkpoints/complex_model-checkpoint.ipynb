# %%
# Pandas dtypes to load for training

train_dtypes = {
    'ProductName':                                                  'float32',
    'IsBeta':                                                       'float32',
    'RtpStateBitfield':                                             'float32',
    'IsSxsPassiveMode':                                             'float32',
    'DefaultBrowsersIdentifier':                                    'float32',
    'AVProductStatesIdentifier':                                    'float32',
    'AVProductsInstalled':                                          'float32',
    'AVProductsEnabled':                                            'float32',
    'HasTpm':                                                       'float32',
    'CountryIdentifier':                                            'float32',
    'CityIdentifier':                                               'float32',
    'OrganizationIdentifier':                                       'float32',
    'GeoNameIdentifier':                                            'float32',
    'LocaleEnglishNameIdentifier':                                  'float32',
    'Platform':                                                     'float32',
    'Processor':                                                    'float32',
    'OsVer':                                                        'float32',
    'OsBuild':                                                      'float32',
    'OsSuite':                                                      'float32',
    'OsPlatformSubRelease':                                         'float32',
    'OsBuildLab':                                                   'float32',
    'SkuEdition':                                                   'float32',
    'IsProtected':                                                  'float32',
    'AutoSampleOptIn':                                              'float32',
    'PuaMode':                                                      'float32',
    'SMode':                                                        'float32',
    'IeVerIdentifier':                                              'float32',
    'SmartScreen':                                                  'float32',
    'Firewall':                                                     'float32',
    'UacLuaenable':                                                 'float32',
    'Census_MDC2FormFactor':                                        'float32',
    'Census_DeviceFamily':                                          'float32',
    'Census_OEMNameIdentifier':                                     'float32',
    'Census_OEMModelIdentifier':                                    'float32',
    'Census_ProcessorCoreCount':                                    'float32',
    'Census_ProcessorManufacturerIdentifier':                       'float32',
    'Census_ProcessorModelIdentifier':                              'float32',
    'Census_ProcessorClass':                                        'float32',
    'Census_PrimaryDiskTotalCapacity':                              'float32',
    'Census_PrimaryDiskTypeName':                                   'float32',
    'Census_SystemVolumeTotalCapacity':                             'float32',
    'Census_HasOpticalDiskDrive':                                   'float32',
    'Census_TotalPhysicalRAM':                                      'float32',
    'Census_ChassisTypeName':                                       'float32',
    'Census_InternalPrimaryDiagonalDisplaySizeInInches':            'float32',
    'Census_InternalPrimaryDisplayResolutionHorizontal':            'float32',
    'Census_InternalPrimaryDisplayResolutionVertical':              'float32',
    'Census_PowerPlatformRoleName':                                 'float32',
    'Census_InternalBatteryType':                                   'float32',
    'Census_InternalBatteryNumberOfCharges':                        'float32',
    'Census_OSArchitecture':                                        'float32',
    'Census_OSBranch':                                              'float32',
    'Census_OSBuildNumber':                                         'float32',
    'Census_OSBuildRevision':                                       'float32',
    'Census_OSEdition':                                             'float32',
    'Census_OSSkuName':                                             'float32',
    'Census_OSInstallTypeName':                                     'float32',
    'Census_OSInstallLanguageIdentifier':                           'float32',
    'Census_OSUILocaleIdentifier':                                  'float32',
    'Census_OSWUAutoUpdateOptionsName':                             'float32',
    'Census_IsPortableOperatingSystem':                             'float32',
    'Census_GenuineStateName':                                      'float32',
    'Census_ActivationChannel':                                     'float32',
    'Census_IsFlightingInternal':                                   'float32',
    'Census_IsFlightsDisabled':                                     'float32',
    'Census_FlightRing':                                            'float32',
    'Census_ThresholdOptIn':                                        'float32',
    'Census_FirmwareManufacturerIdentifier':                        'float32',
    'Census_FirmwareVersionIdentifier':                             'float32',
    'Census_IsSecureBootEnabled':                                   'float32',
    'Census_IsWIMBootEnabled':                                      'float32',
    'Census_IsVirtualDevice':                                       'float32',
    'Census_IsTouchEnabled':                                        'float32',
    'Census_IsPenCapable':                                          'float32',
    'Census_IsAlwaysOnAlwaysConnectedCapable':                      'float32',
    'Wdft_IsGamer':                                                 'float32',
    'Wdft_RegionIdentifier':                                        'float32',
    'EngineVersion_1':                                              'int8',
    'EngineVersion_2':                                              'int8',
    'EngineVersion_3':                                              'float32',
    'EngineVersion_4':                                              'float32',
    'AppVersion_1':                                                 'int8',
    'AppVersion_2':                                                 'float32',
    'AppVersion_3':                                                 'float32',
    'AppVersion_4':                                                 'float32',
    'AvSigVersion_1':                                               'float32',
    'AvSigVersion_2':                                               'float32',
    'AvSigVersion_3':                                               'float32',
    'AvSigVersion_4':                                               'int8',
    'Census_OSVersion_1':                                           'float32',
    'Census_OSVersion_2':                                           'float32',
    'Census_OSVersion_3':                                           'float32',
    'Census_OSVersion_4':                                           'float32',
    'HasDetections':                                                'int8',
}

# %%
# Pandas dtype to load for testing

testing_dtypes = {
    'ProductName': 'float64', 
    'EngineVersion': 'float64', 
    'AppVersion': 'float64', 
    'AvSigVersion': 'float64', 
    'IsBeta': 'float64', 
    'RtpStateBitfield': 'float64', 
    'IsSxsPassiveMode': 'float64', 
    'DefaultBrowsersIdentifier': 'float64', 
    'AVProductStatesIdentifier': 'float64', 
    'AVProductsInstalled': 'float64', 
    'AVProductsEnabled': 'float64', 
    'HasTpm': 'float64', 
    'CountryIdentifier': 'float64', 
    'CityIdentifier': 'float64', 
    'OrganizationIdentifier': 'float64', 
    'GeoNameIdentifier': 'float64', 
    'LocaleEnglishNameIdentifier': 'float64', 
    'Platform': 'float64', 
    'Processor': 'float64', 
    'OsVer': 'float64', 
    'OsBuild': 'float64', 
    'OsSuite': 'float64', 
    'OsPlatformSubRelease': 'float64', 
    'OsBuildLab': 'float64', 
    'SkuEdition': 'float64', 
    'IsProtected': 'float64', 
    'AutoSampleOptIn': 'float64', 
    'PuaMode': 'float64', 
    'SMode': 'float64', 
    'IeVerIdentifier': 'float64', 
    'SmartScreen': 'float64', 
    'Firewall': 'float64', 
    'UacLuaenable': 'float64', 
    'Census_MDC2FormFactor': 'float64', 
    'Census_DeviceFamily': 'float64', 
    'Census_OEMNameIdentifier': 'float64', 
    'Census_OEMModelIdentifier': 'float64', 
    'Census_ProcessorCoreCount': 'float64', 
    'Census_ProcessorManufacturerIdentifier': 'float64', 
    'Census_ProcessorModelIdentifier': 'float64', 
    'Census_ProcessorClass': 'float64', 
    'Census_PrimaryDiskTotalCapacity': 'float64', 
    'Census_PrimaryDiskTypeName': 'float64', 
    'Census_SystemVolumeTotalCapacity': 'float64', 
    'Census_HasOpticalDiskDrive': 'float64', 
    'Census_TotalPhysicalRAM': 'float64', 
    'Census_ChassisTypeName': 'float64', 
    'Census_InternalPrimaryDiagonalDisplaySizeInInches': 'float64', 
    'Census_InternalPrimaryDisplayResolutionHorizontal': 'float64', 
    'Census_InternalPrimaryDisplayResolutionVertical': 'float64', 
    'Census_PowerPlatformRoleName': 'float64', 
    'Census_InternalBatteryType': 'float64', 
    'Census_InternalBatteryNumberOfCharges': 'float64', 
    'Census_OSVersion': 'float64', 
    'Census_OSArchitecture': 'float64', 
    'Census_OSBranch': 'float64', 
    'Census_OSBuildNumber': 'float64', 
    'Census_OSBuildRevision': 'float64', 
    'Census_OSEdition': 'float64', 
    'Census_OSSkuName': 'float64', 
    'Census_OSInstallTypeName': 'float64', 
    'Census_OSInstallLanguageIdentifier': 'float64', 
    'Census_OSUILocaleIdentifier': 'float64', 
    'Census_OSWUAutoUpdateOptionsName': 'float64', 
    'Census_IsPortableOperatingSystem': 'float64', 
    'Census_GenuineStateName': 'float64', 
    'Census_ActivationChannel': 'float64', 
    'Census_IsFlightingInternal': 'float64', 
    'Census_IsFlightsDisabled': 'float64', 
    'Census_FlightRing': 'float64', 
    'Census_ThresholdOptIn': 'float64', 
    'Census_FirmwareManufacturerIdentifier': 'float64', 
    'Census_FirmwareVersionIdentifier': 'float64', 
    'Census_IsSecureBootEnabled': 'float64', 
    'Census_IsWIMBootEnabled': 'float64', 
    'Census_IsVirtualDevice': 'float64', 
    'Census_IsTouchEnabled': 'float64', 
    'Census_IsPenCapable': 'float64', 
    'Census_IsAlwaysOnAlwaysConnectedCapable': 'float64', 
    'Wdft_IsGamer': 'float64', 
    'Wdft_RegionIdentifier': 'float64'
}

# %%
# Import statements

import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
from tqdm.notebook import tqdm
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# Define location of training and valing data

train_dir='/Users/dragonfruit/cs6140-ml-workspace/ML-project/data/train_data_scaled_encoded_shrunk.csv'
val_dir='/Users/dragonfruit/cs6140-ml-workspace/ML-project/data/validation_data_scaled_encoded_shrunk.csv'

# %%
def plot_train_accuracy(train_accuracies, val_accuracies=None, record_interval=2):
    """
    Plots the training accuracy over epochs, considering recording intervals.

    Parameters:
        train_accuracies (list): A list of training accuracy values recorded every `record_interval` epochs.
        val_accuracies (list, optional): A list of validation accuracy values recorded every `record_interval` epochs.
        record_interval (int): The interval at which accuracy is recorded (default is 2 epochs).
    """
    epochs = list(range(record_interval, (len(train_accuracies) * record_interval) + 1, record_interval))

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, train_accuracies, label='Training Accuracy', marker='o', linestyle='-')

    if val_accuracies:
        plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='s', linestyle='--')

    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training Accuracy Over Epochs')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Complex Model - Baseline
#
# * 100 epochs
# * Train loader batch size: 4096
# * val loader batch size: 4096

# %%
# Load training and valing data into Pandas

train=pd.read_csv(train_dir, dtype=train_dtypes)
X_train_scaled = train.drop(columns=['HasDetections'])
y_train = train['HasDetections']

del train

val=pd.read_csv(val_dir, dtype=train_dtypes)
X_val_scaled = val.drop(columns=['HasDetections'])
y_val = val['HasDetections']

del val

# %%
# Define complex model
class BinaryClassifier(nn.Module):
    def __init__(self, input_dim):
        super(BinaryClassifier, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.3),

            nn.Linear(256, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.4),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.4),

            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

# %%
class EnhancedBinaryClassifier(nn.Module):
    def __init__(self, input_dim):
        super(EnhancedBinaryClassifier, self).__init__()

        self.fc1 = nn.Linear(input_dim, 1024)
        self.bn1 = nn.BatchNorm1d(1024)
        self.dropout1 = nn.Dropout(0.3)

        self.fc2 = nn.Linear(1024, 512)
        self.bn2 = nn.BatchNorm1d(512)
        self.dropout2 = nn.Dropout(0.3)

        self.fc3 = nn.Linear(512, 256)
        self.bn3 = nn.BatchNorm1d(256)
        self.dropout3 = nn.Dropout(0.4)

        self.fc4 = nn.Linear(256, 128)
        self.bn4 = nn.BatchNorm1d(128)
        self.dropout4 = nn.Dropout(0.4)

        self.fc5 = nn.Linear(128, 64)
        self.bn5 = nn.BatchNorm1d(64)
        self.dropout5 = nn.Dropout(0.5)

        self.fc6 = nn.Linear(64, 32)
        self.bn6 = nn.BatchNorm1d(32)
        self.dropout6 = nn.Dropout(0.5)

        self.output = nn.Linear(32, 1)

    def forward(self, x):
        x = F.silu(self.bn1(self.fc1(x)))  # Using Swish (SiLU) instead of ReLU
        x = self.dropout1(x)

        x = F.silu(self.bn2(self.fc2(x)))
        x = self.dropout2(x)

        x = F.silu(self.bn3(self.fc3(x)))
        x = self.dropout3(x)

        x = F.silu(self.bn4(self.fc4(x)))
        x = self.dropout4(x)

        x = F.silu(self.bn5(self.fc5(x)))
        x = self.dropout5(x)

        x = F.silu(self.bn6(self.fc6(x)))
        x = self.dropout6(x)

        return torch.sigmoid(self.output(x))  # Final binary classification output

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train_scaled.values, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val_scaled.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).view(-1, 1)

# Create datasets and data loaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

train_batch_size = 4096
val_batch_size = 4096

# Pin memory only speeds up CPU to GPU transfers if the device is CUDA enabled
if torch.cuda.is_available():
    train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=val_batch_size, shuffle=False, pin_memory=True)
else:
    train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=val_batch_size, shuffle=False)

# %%
# Define training variables

input_dim = X_train_tensor.shape[1]
model = BinaryClassifier(input_dim)

# Use AdamW optimizer
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)
criterion = nn.BCELoss()

# Learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, min_lr=1e-6)

# Epochs
epochs = 100

# Figure out which device to use. By default, CPU
device = "cpu"
# For M-architecture Macs
if torch.backends.mps.is_available():
    device = torch.device("mps")
# For NVIDIA
elif torch.cuda.is_available():
    device = torch.device("cuda")

# %%
# Transfer the tensors to the appropriate device
X_train_tensor = X_train_tensor.to(device)
X_val_tensor = X_val_tensor.to(device)
y_train_tensor = y_train_tensor.to(device)
y_val_tensor = y_val_tensor.to(device)

# Transfer the model to the appropriate device
model.to(device)
        
total_train_accuracies = []
total_val_accuracies = []

for epoch in range(epochs):
    model.train()
    # Initialize training loss
    total_train_loss = 0.0
    with tqdm(train_loader, desc=f"Epochs: {epoch+1}/{epochs}") as pbar:
        for inputs, targets in pbar:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_train_loss += loss.item()
            loss.backward()
            optimizer.step()
            # Delete after use
            del inputs, targets, loss
        # Calculate the average training loss
        average_train_loss = total_train_loss / len(train_loader)

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, targets).item()
            # Delete after use
            del inputs, targets
    val_loss /= len(val_loader)
    scheduler.step(val_loss)

    # Print learning rate
    current_lr = optimizer.param_groups[0]['lr']
    print(f'Epoch {epoch+1}/{epochs}, Training Loss: {average_train_loss:.4f}, Validation Loss: {val_loss:.4f}, Learning Rate: {current_lr:.6f}')

    # Print accuracies every other epoch
    if (epoch + 1) % 2 == 0:
        train_accuracies = []
        val_accuracies = []

        model.eval()
        with torch.no_grad():
            # Process train data in batches
            for inputs, targets in DataLoader(train_dataset, batch_size=train_batch_size):
                inputs = inputs.to(device)
                outputs = model(inputs)
                preds = (outputs > 0.5).int().cpu().numpy()
                targets = targets.cpu().numpy()
                train_accuracies.append(accuracy_score(targets, preds))
                del inputs, outputs, preds, targets

            # Process val data in batches
            for inputs, targets in DataLoader(val_dataset, batch_size=val_batch_size):
                inputs = inputs.to(device)
                outputs = model(inputs)
                preds = (outputs > 0.5).int().cpu().numpy()
                targets = targets.cpu().numpy()
                val_accuracies.append(accuracy_score(targets, preds))
                del inputs, outputs, preds, targets

        train_accuracy = sum(train_accuracies) / len(train_accuracies)
        val_accuracy = sum(val_accuracies) / len(val_accuracies)
        total_train_accuracies.append(train_accuracy)
        total_val_accuracies.append(val_accuracy)

        print(f"Train Accuracy in epoch {epoch+1}: {train_accuracy:.4f} | val Accuracy in epoch {epoch+1}: {val_accuracy:.4f}")
    
    if (epoch + 1) % 10 == 0 or (epoch + 1) % epochs == 0:
        # Every 10 epochs or on the final epoch, save the trained model weights after training 
        torch.save(model.state_dict(), f'complex_model_baseline_epoch_{epoch+1}.pth')
        print(f"Trained model weights saved to complex_model_baseline_epoch_{epoch+1}.pth")
# Out:
# Epochs: 1/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 1/100, Training Loss: 0.6706, Validation Loss: 0.6498, Learning Rate: 0.000100
# Epochs: 2/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 2/100, Training Loss: 0.6445, Validation Loss: 0.6387, Learning Rate: 0.000100
# Train Accuracy in epoch 2: 0.6326 | val Accuracy in epoch 2: 0.6255
# Epochs: 3/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 3/100, Training Loss: 0.6366, Validation Loss: 0.6355, Learning Rate: 0.000100
# Epochs: 4/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 4/100, Training Loss: 0.6331, Validation Loss: 0.6338, Learning Rate: 0.000100
# Train Accuracy in epoch 4: 0.6387 | val Accuracy in epoch 4: 0.6283
# Epochs: 5/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 5/100, Training Loss: 0.6309, Validation Loss: 0.6324, Learning Rate: 0.000100
# Epochs: 6/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# ...

# %%
# Plot the train and validation accuracies
plot_train_accuracy(total_train_accuracies, total_val_accuracies)

# %% [markdown]
# # Complex Model - PCA-selected Features
#
# * 100 epochs
# * Train loader batch size: 4096
# * val loader batch size: 4096

# %%
# PCA features
features = [
    "Census_OSBuildNumber",
    "OsBuild",
    "Census_InternalBatteryType",
    "Census_InternalBatteryNumberOfCharges",
    "Census_IsWIMBootEnabled",
    "Census_ThresholdOptIn",
    "OsVer",
    "Platform",
    "Census_ChassisTypeName",
    "Census_MDC2FormFactor",
    "Census_InternalPrimaryDisplayResolutionVertical",
    "Census_OSSkuName",
    "AppVersion",
    "Census_OSEdition",
    "OsSuite",
    "Census_InternalPrimaryDisplayResolutionHorizontal",
    "Census_InternalPrimaryDiagonalDisplaySizeInInches",
    "SkuEdition",
    "OsBuildLab",
    "Census_OSVersion",
    "SmartScreen",
    "Census_TotalPhysicalRAM",
    "Census_OSBranch",
    "Census_PowerPlatformRoleName",
    "ProductName",
    "Census_IsFlightingInternal",
    "HasTpm",
    "Census_ProcessorCoreCount",
    "Census_OSBuildRevision",
    "OsPlatformSubRelease",
    "Census_IsFlightsDisabled",
    "Census_FirmwareManufacturerIdentifier",
    "Census_IsSecureBootEnabled",
    "Firewall",
    "Census_FlightRing",
    "Census_PrimaryDiskTypeName",
    "EngineVersion",
    "IeVerIdentifier",
    "Census_ProcessorModelIdentifier",
    "Census_FirmwareVersionIdentifier",
    "Census_ProcessorClass",
    "AVProductsInstalled",
    "Wdft_IsGamer",
    "Census_OEMNameIdentifier",
    "IsProtected",
    "Processor",
    "Census_OSArchitecture",
    "AVProductStatesIdentifier",
    "SMode",
    "Census_OEMModelIdentifier",
    "Wdft_RegionIdentifier",
    "Census_OSInstallLanguageIdentifier",
    "DefaultBrowsersIdentifier",
    "AVProductsEnabled",
    "Census_GenuineStateName",
    "AvSigVersion",
    "Census_OSWUAutoUpdateOptionsName"
]

# %%
# Load training and valing data into Pandas

train=pd.read_csv(train_dir, dtype=train_dtypes)
X_train_scaled = train[features]
y_train = train['HasDetections']

del train

val=pd.read_csv(val_dir, dtype=train_dtypes)
X_val_scaled = val[features]
y_val = val['HasDetections']

del val

# %%
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train_scaled.values, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val_scaled.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.float32).view(-1, 1)

# Create datasets and data loaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

train_batch_size = 4096
val_batch_size = 4096

# Pin memory only speeds up CPU to GPU transfers if the device is CUDA enabled
if torch.cuda.is_available():
    train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=val_batch_size, shuffle=False, pin_memory=True)
else:
    train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=val_batch_size, shuffle=False)

# %%
# Define training variables

input_dim = X_train_tensor.shape[1]
model = EnhancedBinaryClassifier(input_dim)

# Use AdamW optimizer
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)
criterion = nn.BCEWithLogitsLoss()

# Learning rate scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, min_lr=1e-6)

# Epochs
epochs = 100

# Figure out which device to use. By default, CPU
device = "cpu"
# For M-architecture Macs
if torch.backends.mps.is_available():
    device = torch.device("mps")
# For NVIDIA
elif torch.cuda.is_available():
    device = torch.device("cuda")

# %%
# Transfer the tensors to the appropriate device
X_train_tensor = X_train_tensor.to(device)
X_val_tensor = X_val_tensor.to(device)
y_train_tensor = y_train_tensor.to(device)
y_val_tensor = y_val_tensor.to(device)

# Transfer the model to the appropriate device
model.to(device)
        
total_train_accuracies = []
total_val_accuracies = []

for epoch in range(epochs):
    model.train()
    # Initialize training loss
    total_train_loss = 0.0
    with tqdm(train_loader, desc=f"Epochs: {epoch+1}/{epochs}") as pbar:
        for inputs, targets in pbar:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_train_loss += loss.item()
            loss.backward()
            optimizer.step()
            # Delete after use
            del inputs, targets, loss
        # Calculate the average training loss
        average_train_loss = total_train_loss / len(train_loader)

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, targets).item()
            # Delete after use
            del inputs, targets
    val_loss /= len(val_loader)
    scheduler.step(val_loss)

    # Print learning rate
    current_lr = optimizer.param_groups[0]['lr']
    print(f'Epoch {epoch+1}/{epochs}, Training Loss: {average_train_loss:.4f}, Validation Loss: {val_loss:.4f}, Learning Rate: {current_lr:.6f}')

    # Print accuracies every other epoch
    if (epoch + 1) % 2 == 0:
        train_accuracies = []
        val_accuracies = []

        model.eval()
        with torch.no_grad():
            # Process train data in batches
            for inputs, targets in DataLoader(train_dataset, batch_size=train_batch_size):
                inputs = inputs.to(device)
                outputs = model(inputs)
                preds = (outputs > 0.5).int().cpu().numpy()
                targets = targets.cpu().numpy()
                train_accuracies.append(accuracy_score(targets, preds))
                del inputs, outputs, preds, targets

            # Process val data in batches
            for inputs, targets in DataLoader(val_dataset, batch_size=val_batch_size):
                inputs = inputs.to(device)
                outputs = model(inputs)
                preds = (outputs > 0.5).int().cpu().numpy()
                targets = targets.cpu().numpy()
                val_accuracies.append(accuracy_score(targets, preds))
                del inputs, outputs, preds, targets

        train_accuracy = sum(train_accuracies) / len(train_accuracies)
        val_accuracy = sum(val_accuracies) / len(val_accuracies)
        total_train_accuracies.append(train_accuracy)
        total_val_accuracies.append(val_accuracy)

        print(f"Train Accuracy in epoch {epoch+1}: {train_accuracy:.4f} | val Accuracy in epoch {epoch+1}: {val_accuracy:.4f}")
    
    if (epoch + 1) % 10 == 0 or (epoch + 1) % epochs == 0:
        # Every 10 epochs or on the final epoch, save the trained model weights after training 
        torch.save(model.state_dict(), f'complex_enhanced_model_baseline_epoch_{epoch+1}.pth')
        print(f"Trained model weights saved to complex_enhanced_model_baseline_epoch_{epoch+1}.pth")
# Out:
# Epochs: 1/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 1/100, Training Loss: 0.6835, Validation Loss: 0.6680, Learning Rate: 0.000100
# Epochs: 2/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 2/100, Training Loss: 0.6669, Validation Loss: 0.6657, Learning Rate: 0.000100
# Train Accuracy in epoch 2: 0.6028 | val Accuracy in epoch 2: 0.5969
# Epochs: 3/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 3/100, Training Loss: 0.6647, Validation Loss: 0.6649, Learning Rate: 0.000100
# Epochs: 4/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 4/100, Training Loss: 0.6638, Validation Loss: 0.6646, Learning Rate: 0.000100
# Train Accuracy in epoch 4: 0.6055 | val Accuracy in epoch 4: 0.6042
# Epochs: 5/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# Epoch 5/100, Training Loss: 0.6632, Validation Loss: 0.6643, Learning Rate: 0.000100
# Epochs: 6/100:   0%|          | 0/1743 [00:00<?, ?it/s]
# ...

# %%
# Plot the train and validation accuracies
plot_train_accuracy(total_train_accuracies, total_val_accuracies)
